# %%
import pandas as pd

# %%
data = pd.read_csv('GB1_fitness.csv')
data = data.drop(['EvMutation', 'fit_preds', 'indep_fit'], axis =1)
data = data.rename(columns={"Triad-FixedBb-dG": "zs score"})
data
# Out:
#        Combo                 muts       fit   zs score  num_muts
# 0       AMHG  V39A:D40M:G41H:V54G  0.000000  147.39927         4
# 1       QPEI  V39Q:D40P:G41E:V54I  0.000000   53.49178         4
# 2       GMYW  V39G:D40M:G41Y:V54W  0.000000  134.21443         4
# 3       KWNA  V39K:D40W:G41N:V54A  0.001791  145.52714         4
# 4       QDRA       V39Q:G41R:V54A  0.004730  139.14162         3
# ...      ...                  ...       ...        ...       ...
# 149356  CCRA  V39C:D40C:G41R:V54A  0.009981  141.02978         4
# 149357  QSSK  V39Q:D40S:G41S:V54K  0.004755  145.35619         4
# 149358  IAFG  V39I:D40A:G41F:V54G  3.028731  149.25890         4
# 149359  TILI  V39T:D40I:G41L:V54I  0.003469  141.88873         4
# 149360  LLPC  V39L:D40L:G41P:V54C  0.008662   76.27056         4
#
# [149361 rows x 5 columns]

# %%
data.to_csv('GB1_fitness.csv', index=False)
